# %%
# Loading Image from URL
from urllib.request import urlopen
from io import BytesIO
url = "https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcT0lj5jW2pykKJE--wlBR5SBUrCpcZPfBzxsA&s"
img_data = urlopen(url)
img = Image.open(BytesIO(img_data.read()))

# Display Image
display(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=196x257>

# %%
# Loading Image from local
img = Image.open("image/macWallPaper.jpeg")
width, height = img.size

# Display Image
display(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=853x480>
